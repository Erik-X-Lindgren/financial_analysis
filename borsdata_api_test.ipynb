# %%
import requests

API_KEY = '9681b53e1aec4d0f9e54d50c701ba1f4'
URL = 'https://apiservice.borsdata.se/v1/instruments?authKey=9681b53e1aec4d0f9e54d50c701ba1f4'

headers = {
    'accept': 'application/json'
}

response = requests.get(URL, headers=headers)

# %%
if response.ok:
    data = response.json()

# %%
data
# Out:
# {'instruments': [{'insId': 2,
#    'name': 'AAK',
#    'urlName': 'aarhuskarlshamn',
#    'instrument': 0,
#    'isin': 'SE0011337708',
#    'ticker': 'AAK',
#    'yahoo': 'AAK.ST',
#    'sectorId': 2,
#    'marketId': 1,
#    'branchId': 63,
#    'countryId': 1,
#    'listingDate': '2005-09-29T00:00:00',
#    'stockPriceCurrency': 'SEK',
#    'reportCurrency': 'SEK'},
#   {'insId': 3,
#    'name': 'ABB',
#    'urlName': 'abb',
#    'instrument': 0,
#    'isin': 'CH0012221716',
#    'ticker': 'ABB',
#    'yahoo': 'ABB.ST',
#    'sectorId': 5,
#    'marketId': 1,
#    'branchId': 23,
#    'countryId': 1,
#    'listingDate': '1999-06-22T00:00:00',
#    'stockPriceCurrency': 'SEK',
#    'reportCurrency': 'USD'},
#   {'insId': 6,
#    'name': 'Active Biotech',
#    'urlName': 'active-biotech',
#    'instrument': 0,
#    'isin': 'SE0001137985',
#    'ticker': 'ACTI',
#    'yahoo': 'ACTI.ST',
#    'sectorId': 4,
#    'marketId': 3,
#    'branchId': 78,
#    'countryId': 1,
# ...

# %%
URL = 'https://apiservice.borsdata.se/v1/instruments/2/reports/year?authKey=9681b53e1aec4d0f9e54d50c701ba1f4&maxCount=20&original=1'
response = requests.get(URL, headers=headers)

# %%
if response.ok:
    data = response.json()

# %%
data
# Out:
# {'instrument': 2,
#  'reports': [{'year': 2024,
#    'period': 5,
#    'revenues': 45228.0,
#    'gross_Income': 12996.0,
#    'operating_Income': 4896.0,
#    'profit_Before_Tax': 4660.0,
#    'profit_To_Equity_Holders': 3536.0,
#    'earnings_Per_Share': 13.62,
#    'number_Of_Shares': 259.559,
#    'dividend': 5.0,
#    'intangible_Assets': 2653.0,
#    'tangible_Assets': 8594.0,
#    'financial_Assets': 497.0,
#    'non_Current_Assets': 11744.0,
#    'cash_And_Equivalents': 1911.0,
#    'current_Assets': 22642.0,
#    'total_Assets': 34386.0,
#    'total_Equity': 20149.0,
#    'non_Current_Liabilities': 2533.0,
#    'current_Liabilities': 11704.0,
#    'total_Liabilities_And_Equity': 34386.0,
#    'net_Debt': 1696.0,
#    'cash_Flow_From_Operating_Activities': 2352.0,
#    'cash_Flow_From_Investing_Activities': -598.0,
#    'cash_Flow_From_Financing_Activities': -1326.0,
#    'cash_Flow_For_The_Year': 428.0,
#    'free_Cash_Flow': 1754.0,
#    'stock_Price_Average': 295.4,
# ...
